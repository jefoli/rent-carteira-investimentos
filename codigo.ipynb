# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf

# %%
with open("carteira.txt", "r") as arquivo:
    texto = arquivo.readlines()

carteira = {}

for linha in texto:
    
    ticker, valor = linha.split("-")
    ticker = f"{ticker.strip()}.SA"
    valor = float(valor.strip())
    print(ticker, valor)

    carteira[ticker] = valor

print(carteira)
# Out:
# ITUB4.SA 1000.0
# BBAS3.SA 2000.0
# VALE3.SA 1000.0
# EGIE3.SA 500.0
# SLCE3.SA 300.0
# {'ITUB4.SA': 1000.0, 'BBAS3.SA': 2000.0, 'VALE3.SA': 1000.0, 'EGIE3.SA': 500.0, 'SLCE3.SA': 300.0}

# %%
ativos = list(carteira.keys())
data_inicial = "2024-01-01"
data_final = "2024-12-15"
ativos = yf.download(ativos,start = data_inicial, end = data_final)
tabela_cotacoes = ativos["Close"]

display(tabela_cotacoes)
# Out:
# [*********************100%***********************]  5 of 5 completed
# Ticker       BBAS3.SA   EGIE3.SA   ITUB4.SA   SLCE3.SA   VALE3.SA
# Date
# 2024-01-02  25.262661  41.862675  31.238022  17.552208  70.522316
# 2024-01-03  25.285730  41.843864  30.893198  17.676556  70.156204
# 2024-01-04  25.018154  41.721622  30.688179  17.456556  69.213470
# 2024-01-05  25.318024  41.655804  31.405762  17.714817  68.325645
# 2024-01-08  25.534845  41.354900  31.070265  17.561773  67.977829
# ...               ...        ...        ...        ...        ...
# 2024-12-09  24.498310  37.642559  32.530746  18.680000  59.300713
# 2024-12-10  24.657198  37.672310  32.971054  18.950001  59.241245
# 2024-12-11  25.183510  37.920219  33.290871  19.150000  58.319469
# 2024-12-12  24.850000  36.938499  32.461346  19.010000  56.709999
# 2024-12-13  24.510000  36.760002  32.041588  19.170000  55.860001
#
# [242 rows x 5 columns]
